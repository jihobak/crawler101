# %%
import requests
from bs4 import BeautifulSoup

# %%
BASE_URL = "https://api.siksinhot.com/v1/hp/search/place"

condition = {
    "keywords": "치킨",
    "idx": "24",
    "limit": "12",
    "order": "interest"
}

header= {
    "siksinOauth":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjAsImlhdCI6MTU3NDIzMjY5MiwiZXhwIjoxNTc0MzE5MDkyLCJpc3MiOiJzaWtzaW4ifQ.Sg8t9pgQXR67DSHwM0o7N6R60OiAIb4q8Ko5qFMGwvs"
}

resp = requests.get(BASE_URL, params=condition, headers=header)

# %%
resp.text
# Out:
# '{"data":{"cnt":2959,"list":[{"pid":356994,"pname":"후켄","upHpAreaId":14,"upHpAreaTitle":"전북","hpAreaId":358,"hpAreaTitle":"전주시","hpSchCate":4,"hpSchCateNm":"고기/구이류","mcateNm":"치킨/훈제","bcateNm":null,"cmt":"각종 해산물 튀김도 맛있는 치킨 맛집","lat":35.83295,"lng":127.117686,"addr":"전라북도 전주시 완산구 서신동 765-1","addr2":"전라북도 전주시 완산구 당산로 99","bestOrd":1,"hundredYn":"N","score":3.9,"dist":187606.0,"likeCnt":18,"bookmarkCnt":31,"viewCnt":8622,"callCnt":94,"shareCnt":0,"chkinCnt":0,"rpCnt":11,"photo":{"fileId":7392227,"type":null,"path":"place","imgNm":"1463539750577941.png","movNm":null,"width":529,"height":525},"closeType":"N","parkingYn":"N","valletYn":"N","corkageFreeYn":"N","intro":null,"newYn":null,"phone":null,"upTitle":null,"title":null,"closeMemo":null,"bestYn":null,"videoUrl":null,"videoYn":null,"menu":[{"menuNm":"후라이드 치킨","price":16000,"maxPrice":null,"unit":"원"},{"menuNm":"양념치킨","price":17000,"maxPrice":null,"unit":"원"},{"menuNm":"후라이드 양념 반반","price":17000,"maxPrice":null,"unit":"원"},{"menuNm":"후라
# ...
